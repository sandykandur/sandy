# %%
s=input("enter the string" )
vowel = ['a','e','i','o','u']
for i in s:
    if i in vowel:
        print(chr(ord(i)+1),end="")
    elif(ord(i)>65 and ord(i)<69)or(ord(i)>97 and ord(i)<101):
        print('e',end="")
    elif(ord(i)>69 and ord(i)<73)or(ord(i)>101 and ord(i)<105):
        print('i',end="")
    elif(ord(i)>73 and ord(i)<79)or(ord(i)>105 and ord(i)<111):
        print('o',end="")
    elif(ord(i)>79 and ord(i)<85)or(ord(i)>111 and ord(i)<117):
        print('u',end="")
    elif(ord(i)>85 and ord(i)<90)or(ord(i)>117 and ord(i)<122):
        print('a',end="")
# Out:
# enter the stringorange
# puboif

# %%
input1 = [1,2,2,5,2,1,3,8,4]
s=0
for i in range(len(input1)):
    if i<input1.index(5) or i>input1.index(8):
        s+=input1[i]
print(s)
# Out:
# 9

# %% [markdown]
# ### File handling
# 1. creating a file
# 2. adding content
# 3. saving
# 4. reading
#
# mods-->read(r),write(w),append(a)

# %%
f= open("data.txt","w")
f.write("hello everyone")
f.close()

# %%
f1=open("data.txt","r")
str1=f1.read()
print(str1)
# Out:
# hello everyone

# %%
f1=open("data.txt","r")
str1=f1.read()
print(len(str1))
# Out:
# 14

# %%
pwd
# Out:
# '/content'

# %%
f1=open("data.txt","r")
str1=f1.read()
print(len(str1))#returns no.of character
print(len(str1.split()))#returns no.of words
# Out:
# 14
# 2

# %% [markdown]
# 1. create a folder
# 2. open that folder and create random no.of files with unique name
# 3. add random content into the file
# 4. file size should be 512 bytes
